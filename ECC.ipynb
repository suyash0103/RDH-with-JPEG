# %%
def convert(char):
    return format(ord(char), '09b')

# %%
def polynomial(LHS,RHS,n):
    for i in range(0,n):
        LHS[0].append(i)
        RHS[0].append(i)
        LHS[1].append((i*i*i + a*i + b)%n)
        RHS[1].append((i*i)%n)


def points_generate(arr_x,arr_y,n):
    count=0
    for i in range(0,n):
        for j in range(0,n):
            if(LHS[1][i]==RHS[1][j]):
                count+=1
                arr_x.append(LHS[0][i])
                arr_y.append(RHS[0][j])
    return count

# %%
print("Elliptic Curve General Form:\t y^2 mod n=(x^3  + a*x + b)mod n\nEnter 'n':")

data = ''

#main
n=int(input())
# n = 43
LHS=[[]]
RHS=[[]]
LHS.append([])
RHS.append([])
print("Enter value of 'a':")
a=int(input())
print("Enter value of 'b':")
b=int(input())
# a = 68
# b = 97

#Polynomial
polynomial(LHS,RHS,n)

arr_x=[]
arr_y=[]
#Generating base points
count=points_generate(arr_x,arr_y,n)
    
#Print Generated Points
print("Generated points are:")
for i in range(0,count):
    print(i+1," (",arr_x[i],",",arr_y[i],")\n")



#Calculation of Base Point
bx=arr_x[0]
by=arr_y[0]
print("Base Point taken is:\t(",bx,",",by,")\n")


print("Enter the random number 'd' i.e. Private key of Sender (d<n):")
d=int(input())
# d = 23
if(d>=n):
    print("'d' should be less than 'n'.")
else:
    #Q i.e. sender's public key generation
    Qx=d*bx
    Qy=d*by
    print("Public key of sender is:\t(",Qx,",",Qy,")\n")

    #Encrytion
    print("Enter the random number 'k' (k<n):\n")
    k=int(input())
#     k = 14
    if(k>=n):
        print("'k' should be less than 'n'")
    else:
        print("Enter the message to be sent:\n")
        N=input()
        for i in N:
            data += convert(i)
        M = int(data)

        #Cipher text 1 generation
        C1x=k*bx
        C1y=k*by
        print("Value of Cipher text 1 i.e. C1:\t(",C1x,",",C1y,")\n")

        #Cipher text 2 generation
        C2x=k*Qx+M
        C2y=k*Qy+M
        print("Value of Cipher text 2 i.e. C2:\t(",C2x,",",C2y,")\n")

    #Decryption
        message = ''
        Mx=C2x-d*C1x
        My=C2y-d*C1y
        print("The message recieved by reciever is:\t",Mx)
        data = str(Mx)
        l = len(data)
        div = int(l / 9)
        div += 1
        div = div * 9
        div = div - l
        for i in range(0, div):
            data = '0' + data
        print (data)
        for i in range(0, int(len(data) / 9)):
            substr = data[i * 9 : (i + 1) * 9]
#             print (substr)
            num = int(substr, 2)
#             print (num)
            message += chr(num)
        print (message)
# Out:
# Elliptic Curve General Form:	 y^2 mod n=(x^3  + a*x + b)mod n
# Enter 'n':
# 45
# Enter value of 'a':
# 56
# Enter value of 'b':
# 67
# Generated points are:
# 1  ( 1 , 13 )
#
# 2  ( 1 , 22 )
#
# 3  ( 1 , 23 )
#
# 4  ( 1 , 32 )
#
# 5  ( 4 , 20 )
#
# 6  ( 4 , 25 )
#
# 7  ( 6 , 13 )
#
# 8  ( 6 , 22 )
#
# 9  ( 6 , 23 )
#
# 10  ( 6 , 32 )
#
# 11  ( 9 , 20 )
#
# 12  ( 9 , 25 )
#
# 13  ( 11 , 13 )
#
# 14  ( 11 , 22 )
#
# 15  ( 11 , 23 )
#
# 16  ( 11 , 32 )
#
# 17  ( 14 , 20 )
#
# 18  ( 14 , 25 )
#
# 19  ( 16 , 8 )
#
# 20  ( 16 , 17 )
#
# 21  ( 16 , 28 )
#
# 22  ( 16 , 37 )
#
# 23  ( 19 , 5 )
#
# 24  ( 19 , 40 )
#
# 25  ( 21 , 8 )
#
# 26  ( 21 , 17 )
#
# 27  ( 21 , 28 )
#
# 28  ( 21 , 37 )
#
# 29  ( 24 , 5 )
#
# 30  ( 24 , 40 )
#
# 31  ( 26 , 8 )
#
# 32  ( 26 , 17 )
#
# 33  ( 26 , 28 )
#
# 34  ( 26 , 37 )
#
# 35  ( 29 , 5 )
#
# 36  ( 29 , 40 )
#
# 37  ( 31 , 2 )
#
# 38  ( 31 , 7 )
#
# 39  ( 31 , 38 )
#
# 40  ( 31 , 43 )
#
# 41  ( 34 , 10 )
#
# 42  ( 34 , 35 )
#
# 43  ( 36 , 2 )
#
# 44  ( 36 , 7 )
#
# 45  ( 36 , 38 )
#
# 46  ( 36 , 43 )
#
# 47  ( 39 , 10 )
#
# 48  ( 39 , 35 )
#
# 49  ( 41 , 2 )
#
# 50  ( 41 , 7 )
#
# 51  ( 41 , 38 )
#
# 52  ( 41 , 43 )
#
# 53  ( 44 , 10 )
#
# 54  ( 44 , 35 )
#
# Base Point taken is:	( 1 , 13 )
#
# Enter the random number 'd' i.e. Private key of Sender (d<n):
# 34
# Public key of sender is:	( 34 , 442 )
#
# Enter the random number 'k' (k<n):
#
# 12
# Enter the message to be sent:
#
# Hello
# Value of Cipher text 1 i.e. C1:	( 12 , 156 )
#
# Value of Cipher text 2 i.e. C2:	( 1001000001100101001101100001101100001101519 , 1001000001100101001101100001101100001106415 )
#
# The message recieved by reciever is:	 1001000001100101001101100001101100001101111
# 001001000001100101001101100001101100001101111
# Hello
